# %%
import pandas as pd
import os
import requests
from api_key import api_key, Client_ID, g_key
import numpy as np
from geopy.geocoders import Nominatim
import warnings
warnings.filterwarnings('ignore')

# %%
# Yelp api
import requests
import json
from pprint import pprint
from yelp.client import Client
# from yelp_api_key import yelp_client_id
# from yelp_api_key import yelp_api_key
from urllib.parse import quote
API_KEY = api_key
API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  

DEFAULT_TERM = 'supermarket'
DEFAULT_LOCATION = '1734 E 41st St, Los Angeles, CA 90058'
# DEFAULT_DISTANCE = 5
SEARCH_LIMIT = 50

def request(host, path, api_key, url_params=None):
    
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }
    print(u'Querying {0} ...'.format(url))
    response = requests.request('GET', url, headers=headers, params=url_params)
    return response.json()

response = request(host=API_HOST,
                  path=SEARCH_PATH,
                  api_key=API_KEY,
                  url_params={"location":DEFAULT_LOCATION, "term":DEFAULT_TERM, "limit": SEARCH_LIMIT})

pprint(response, indent=4)
# Out:
# Querying https://api.yelp.com/v3/businesses/search ...
# {   'businesses': [   {   'alias': 'northgate-market-los-angeles-5',
#                           'categories': [   {   'alias': 'bakeries',
#                                                 'title': 'Bakeries'},
#                                             {   'alias': 'grocery',
#                                                 'title': 'Grocery'},
#                                             {   'alias': 'mexican',
#                                                 'title': 'Mexican'}],
#                           'coordinates': {   'latitude': 33.9884528446097,
#                                              'longitude': -118.258182071149},
#                           'display_phone': '(323) 846-8804',
#                           'distance': 2622.5278441124883,
#                           'id': '68t1myg9qVCuxrMOiZFBQQ',
# ...

# %%
# sandbox
x =[]

for i in range(50):
    try:
        x.append(response['businesses'][i]['location']['address1'])
    except:
        x.append(np.NaN)
print(x)
# Out:
# ['944 E Slauson Ave', '788 S Grand Ave', '645 W 9th St', '123 S Onizuka St', '3131 S Hoover St', '2633 Santa Ana St', '333 S Alameda St', '3250 W Olympic Blvd', '1301 E Gage Ave', '7316 Compton Ave', '621 S. Western Ave.', '2600 S Vermont Ave', '300 S Santa Fe Ave', '2465 Fruitland Ave', '4400 Slauson Ave', '124 Japanese Village Plz Mall', '2750 E 1st St', '845 S Figueroa St', '124 North Western Ave', '750 S Alameda St', '3607 S Vermont Ave', '4260 Charter St', '4103 S Hoover St', '650 W 5th St', '860 N Hill St', '7676 Firestone Blvd', '1100 N Main St', '1120 W 6th St', '1100 W Slauson Ave', '4155 Tweedy Blvd', '425 S Soto St', '1342 N Alvarado St', '3300 W Slauson Ave', '7814 Firestone Blvd', '2740 W Olympic Blvd', '7029 Santa Fe Ave', '7300 Atlantic Ave', '6801 S Atlantic Ave', '440 S Vermont Ave', '3607 Trousdale Pkwy', '2323 W Olympic Blvd', '3250 W Olympic Blvd', '5345 Santa Monica Blvd', '3425 Whittier Blvd', '11922 S Vermont Ave', '5325 S Soto St', '420 Stanford Ave', '1631 W 
# ...

# %%
# restaurant_id = []
lat = []
lon = []
supermarket = []
price = []
# category = [] Not needed
# transactions = [] Not Needed
rating = []
address = []
review_count = []


for i in range(50):
    try:
        
        supermarket.append(response['businesses'][i]['name'])
        lat.append(response["businesses"][i]["coordinates"]["latitude"])
        lon.append(response["businesses"][i]["coordinates"]["longitude"])
        
#         category.append(response['businesses'][i]['categories']['title']) Not needed
#         transactions.append(response['businesses'][i]['transactions']) Not needed
        address.append(response['businesses'][i]['location']['address1'])
        rating.append(response['businesses'][i]['rating'])
        review_count.append(response['businesses'][i]['review_count'])
        price.append(response['businesses'][i]['price'])
        
    except:
        price.append(np.NaN)
        pass
    continue


print(f"length of restaurants name :{len(supermarket)}")    
print(f"length of lat :{len(lat)}")
print(f"length of lon :{len(lon)}")
print(f"length of price :{len(price)}") 
# print(f"length of category :{len(category)}")
# print(f"length of transactions :{len(transactions)}")
print(f"length of rating  :{len(rating)}")
print(f"length of addresses :{len(address)}")
print(f"length of review_count :{len(review_count)}")
# Out:
# length of restaurants name :50
# length of lat :50
# length of lon :50
# length of price :50
# length of rating  :50
# length of addresses :50
# length of review_count :50

# %%
# x = [i for i in price]
x =[]
for i in price:
    try:
        x.append(len(i))
    except:
        x.append(np.nan)
print(x)
print(price)
y = pd.DataFrame({'Price':price,
                  'Price_Length':x
                 })
y.Price.value_counts()
# Out:
# [1, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, nan, 2, 2, 1, 1, 2, 2, 1, 1, nan, 1, 1, 2, 1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, nan, 2, 2, 3, 2, 2, 1, 2]
# ['$', '$$', '$$', '$$', '$$', '$', '$$', '$$', '$$', '$', '$$', '$$', '$$', nan, '$$', '$$', '$', '$', '$$', '$$', '$', '$', nan, '$', '$', '$$', '$', '$', '$', '$$', '$$', '$$', '$$', '$$', '$$', '$$', '$', '$$', '$$', '$$', '$$', '$$', nan, '$$', '$$', '$$$', '$$', '$$', '$', '$$']
# $$     32
# $      14
# $$$     1
# Name: Price, dtype: int64

# %%
total_data = {"Latitude": lat,
             "Longitude": lon,
             "Supermarket": supermarket,
             "Address": address, 
             "Rating": rating,
             "Review": review_count,
             "Price": price}
supermarket_df = pd.DataFrame(total_data)
supermarket_df
# Out:
#      Latitude   Longitude                                Supermarket  \
# 0   33.988453 -118.258182                           Northgate Market
# 1   34.045876 -118.257620                         Whole Foods Market
# 2   34.045670 -118.260825                                     Ralphs
# 3   34.050194 -118.242272                             Marukai Market
# 4   34.026096 -118.284665                               Trader Joe's
# 5   33.964691 -118.223984                           Northgate Market
# 6   34.044729 -118.239064                  Little Tokyo Market Place
# 7   34.052344 -118.308386                            Galleria Market
# 8   33.982618 -118.251546                                   El Super
# 9   33.973310 -118.246990                           Superior Grocers
# 10  34.062730 -118.309460                     H Mart - Los Angeles I
# 11  34.032024 -118.290663                                     Ralphs
# 12  34.045259 -118.232425                                  Grow DTLA
# ...

# %%
supermarket_df.to_csv('supermarket_df.csv', index=False)

# %%
supermarket_df[['Latitude','Longitude']].head()
# Out:
#     Latitude   Longitude
# 0  33.988453 -118.258182
# 1  34.045876 -118.257620
# 2  34.045670 -118.260825
# 3  34.050194 -118.242272
# 4  34.026096 -118.284665

# %%
import gmaps
gmaps.configure(api_key=g_key)

# %%
coordinates = supermarket_df[['Latitude','Longitude']]
figure_layout = {
    'width': '720px',
    'height': '720px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
markers = gmaps.marker_layer(coordinates)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='720px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# Now that we can map the coordinates of the supermarkets, the next step will be to find those in a 5 mile radius of the food bank. The link that displays what we need `https://www.mapdevelopers.com/draw-circle-tool.php?circles=%5B%5B8046.7%2C34.0079733%2C-118.2422964%2C%22%23AAAAAA%22%2C%22%23000000%22%2C0.4%5D%5D`
#
# Latitdue (`34.007832`) and Longitude (`-118.242081`) of 1734 E 41st St, Los Angeles, CA 90058 (<a href="https://www.latlong.net/c/?lat=34.007832&long=-118.242081" target="_blank">(34.007832, -118.242081)</a>)

# %% [markdown]
# 1/60 degrees ~ 1 mile therefore 1/12 degrees ~ 5 miles in terms of latitude.
#
# I would assume that this is the same in terms of longitutde, need to do some research

# %%
from  geopy.geocoders import Nominatim
geolocator = Nominatim()
address =  '1734 E 41st St, Los Angeles, CA 90058'
# address_fixed = address
loc = geolocator.geocode(address)
print()
print("latitude is :" ,loc.latitude,"\nlongtitude is:" ,loc.longitude)
# Out:
# latitude is : 34.00797331313131
# longtitude is: -118.2422964040404

# %%
from  geopy.geocoders import Nominatim
geolocator = Nominatim()
address =  '1734 E 41st St, Los Angeles, CA 90058'
# address_fixed = address
loc = geolocator.geocode(address)
# print()
# print("latitude is :" ,loc.latitude,"\nlongtitude is:" ,loc.longitude)
miles =10
rad_lat = [loc.latitude+(((np.sin(x))*miles/2)/60) for x in np.arange(0,2*np.pi, 0.1)]
rad_lon = [loc.longitude+(((np.cos(x))*miles/2)/60) for x in np.arange(0,2*np.pi, 0.1)]


radius = pd.DataFrame({'lat': rad_lat,'lon': rad_lon})

centre = pd.DataFrame({'lat': [loc.latitude],'lon': [loc.longitude]})

figure_layout = {
    'width': '720px',
    'height': '720px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# home_address = '1734 E 41st St, Los Angeles, CA 90058'
# loc = geolocator.geocode(home_address)

# Assign the marker layer to a variable

# Assign the marker layer to a variable
# markers = gmaps.marker_layer(radius)
# heat = add_layer(gmaps.heatmaplayer(data=radius))
# Add the layer to the map
fig.add_layer(gmaps.heatmap_layer(radius))
fig.add_layer(gmaps.marker_layer(centre))
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='720px', margin='0 auto 0 auto', padding='1px', wi…

# %%
# home_coords = [34.007832,-118.242081]

# home_address =  '1734 E 41st St, Los Angeles, CA 90058'

# from  geopy.geocoders import Nominatim
# geolocator = Nominatim()

# ############################################################################
# def coords_around_foodbank(foodbank, miles=5):    
# # This function is used to find the coordinates of the foodbank
# # and find the north, south, west, and east coordinates of that
# # particular foodbank.

#     loc = geolocator.geocode(foodbank)

# #     rad_lat = [loc.latitude+(((np.sin(x))*miles/2)/60) for x in np.arange(0,2*np.pi, 0.5)]
# #     rad_lon = [loc.longitude+(((np.cos(x))*miles/2)/60) for x in np.arange(0,2*np.pi, 0.5)]
    
#     x_miles_n = loc.latitude - (miles/60)
#     x_miles_s = loc.latitude + (miles/60)
#     x_miles_w = loc.longitude - (miles/60)
#     x_miles_e = loc.longitude + (miles/60)
      
#     return x_miles_n, x_miles_s, x_miles_w, x_miles_e
# ############################################################################
# radius_around_foodbank(home_address, 5)

# %%
# home_address =  '1734 E 41st St, Los Angeles, CA 90058'

# supermarkets_filtered = supermarket_df[(supermarket_df['Latitude']>=coords_around_foodbank(home_address)[0])
#                &(supermarket_df['Latitude']<=coords_around_foodbank(home_address)[1])
#                &(supermarket_df['Longitude']>=coords_around_foodbank(home_address)[2])
#                &(supermarket_df['Longitude']<=coords_around_foodbank(home_address)[3])
#               ]
# # I think this gets it out in a square
# # filtered_coordinates = filtered_supermarkets.iloc[:,[0,1]]
# # filtered_coordinates
# supermarkets_filtered[['Latitude','Longitude']]

# %%
foodbank =  '1734 E 41st St, Los Angeles, CA 90058'
# need to put this in a def statment
loc = geolocator.geocode(foodbank)
miles = 5
rad_lat = [loc.latitude+(((np.cos(x))*miles/2)/60) for x in np.arange(0,2*np.pi,0.1)]
rad_lon = [loc.longitude+(((np.sin(x))*miles/2)/60) for x in np.arange(0,2*np.pi,0.1)]

supermarkets_filtered_v1 = supermarket_df[(supermarket_df['Latitude']>=min(rad_lat)) 
                                    & (supermarket_df['Latitude']<=max(rad_lat))
                                    & (supermarket_df['Longitude']<=max(rad_lon))
                                    & (supermarket_df['Longitude']>=min(rad_lon))]
# supermarkets_filtered
print(f"latitude:{loc.latitude}, longitude:{loc.longitude}")
print(f"rad_lat:\n{max(rad_lat)}")
print(f"rad_lon:\n{rad_lon}")

supermarkets_filtered_v1
# Out:
# latitude:34.00797331313131, longitude:-118.2422964040404
# rad_lat:
# 34.04963997979797
# rad_lon:
# ...

# %%
# r = 5


# a = [[r*np.cos(x),r*np.sin(x)] for x in np.arange(0,2*np.pi,0.1)]
# a
# # b = [r*np.sin(x) for x in np.arange(0,2*np.pi, 0.1)]


# from  geopy.geocoders import Nominatim
# geolocator = Nominatim()
# address =  '1734 E 41st St, Los Angeles, CA 90058'
# # address_fixed = address
# loc = geolocator.geocode(address)
# print()
# print("latitude is :" ,loc.latitude,"\nlongtitude is:" ,loc.longitude)

# rad_lat = [loc.latitude+np.sin(x) for x in np.arange(0,2*np.pi, 0.1)]
# rad_lon = [loc.longitude+np.cos(x) for x in np.arange(0,2*np.pi, 0.1)]


# print(f"""
#        rad_lat: {rad_lat}
       
#        rad_lon: {rad_lon}
#        """
# )
# len(rad_lat)

# This was all testing

# %%
# heatmat of the supermarkets

coordinates = supermarkets_filtered_v1[['Latitude','Longitude']]

figure_layout = {
    'width': '720px',
    'height': '720px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# home_address = '1734 E 41st St, Los Angeles, CA 90058'
# loc = geolocator.geocode(home_address)

# Assign the marker layer to a variable

# Assign the marker layer to a variable
# markers = gmaps.marker_layer(coordinates)

fig.add_layer(gmaps.marker_layer(coordinates, display_info_box=None))

# Add the layer to the map
              
              
fig.add_layer(gmaps.symbol_layer(radius, fill_color='blue', stroke_color='blue', scale=4))
fig.add_layer(gmaps.symbol_layer(centre, fill_color='black', stroke_color='black', scale=3, info_box_content=address))

# fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='720px', margin='0 auto 0 auto', padding='1px', wi…
